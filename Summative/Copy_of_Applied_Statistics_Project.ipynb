# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Data Loading**

# %%
superstore = pd.read_csv('/content/drive/MyDrive/Module 5 Applied Statistics/Summative Project/Superstore Marketing Data.csv')

# %%
superstore
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# ## **Determine NUlls**

# %%
superstore.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %% [markdown]
# ## **Removing NUlls**

# %%
superstore['Income'].fillna(superstore['Income'].mean(),inplace=True)

# %%
superstore.isnull().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# dtype: int64

# %%
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# ## **Descriptive Statistics of Corrected Data**

# %%
superstore.drop(['Id','Year_Birth'],axis=1).describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2240.000000  2240.000000  2240.000000  2240.000000  2240.000000
# mean    52247.251354     0.444196     0.506250    49.109375   303.935714
# std     25037.797168     0.538398     0.544538    28.962453   336.597393
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35538.750000     0.000000     0.000000    24.000000    23.750000
# 50%     51741.500000     0.000000     0.000000    49.000000   173.500000
# 75%     68289.750000     1.000000     1.000000    74.000000   504.250000
# max    666666.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2240.000000      2240.000000      2240.000000       2240.000000
# mean     26.302232       166.950000        37.525446         27.062946
# std      39.773434       225.715373        54.628979         41.280498
# ...

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %%
stats = superstore.drop(['Id','Year_Birth'],axis=1).describe()
stats.loc['var'] = superstore.drop(['Id','Year_Birth'],axis=1).var().tolist()
stats.loc['skew'] = superstore.drop(['Id','Year_Birth'],axis=1).skew().tolist()
stats.loc['kurt'] = superstore.drop(['Id','Year_Birth'],axis=1).kurtosis().tolist()
desc = pd.DataFrame(stats)
desc
# Out:
# <ipython-input-11-d55047d701c8>:2: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   stats.loc['var'] = superstore.drop(['Id','Year_Birth'],axis=1).var().tolist()
# <ipython-input-11-d55047d701c8>:3: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   stats.loc['skew'] = superstore.drop(['Id','Year_Birth'],axis=1).skew().tolist()
# ...

# %% [markdown]
# ## **Detecting Outliers**

# %%
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# # **Income**

# %%
sns.boxplot(superstore.Income)
Q1 = superstore.Income.quantile(0.25)
Q3 = superstore.Income.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
superstore = superstore[ (superstore.Income >= lower_bound) & (superstore.Income <= upper_bound) ]
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2232 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2232 non-null   int64
#  1   Year_Birth           2232 non-null   int64
#  2   Education            2232 non-null   object
#  3   Marital_Status       2232 non-null   object
#  4   Income               2232 non-null   float64
#  5   Kidhome              2232 non-null   int64
#  6   Teenhome             2232 non-null   int64
#  7   Dt_Customer          2232 non-null   object
#  8   Recency              2232 non-null   int64
#  9   MntWines             2232 non-null   int64
#  10  MntFruits            2232 non-null   int64
#  11  MntMeatProducts      2232 non-null   int64
#  12  MntFishProducts      2232 non-null   int64
#  13  MntSweetProducts     2232 non-null   int64
#  14  MntGoldProds         2232 non-null   int64
# ...

# %%
sns.boxplot(superstore.Income)
# Out:
# <Axes: ylabel='Income'>

# %% [markdown]
# # **MntFishProducts**

# %%
sns.boxplot(superstore.MntFishProducts)
# Out:
# <Axes: ylabel='MntFishProducts'>

# %% [markdown]
# # **MntFruits**

# %%
sns.boxplot(superstore.MntFruits)
# Out:
# <Axes: ylabel='MntFruits'>

# %% [markdown]
# # **MntGoldProds**

# %%
sns.boxplot(superstore.MntGoldProds)
# Out:
# <Axes: ylabel='MntGoldProds'>

# %% [markdown]
# # **MntMeatProducts**

# %%
sns.boxplot(superstore.MntMeatProducts)
# Out:
# <Axes: ylabel='MntMeatProducts'>

# %% [markdown]
# # **MntSweetProducts**

# %%
sns.boxplot(superstore.MntSweetProducts)
# Out:
# <Axes: ylabel='MntSweetProducts'>

# %% [markdown]
# # **MntWines**

# %%
sns.boxplot(superstore.MntWines)
# Out:
# <Axes: ylabel='MntWines'>

# %% [markdown]
# # **NumCatalogPurchases**

# %%
sns.boxplot(superstore.NumCatalogPurchases)
# Out:
# <Axes: ylabel='NumCatalogPurchases'>

# %% [markdown]
# # **NumDealsPurchases**

# %%
sns.boxplot(superstore.NumDealsPurchases)
Q1 = superstore.NumDealsPurchases.quantile(0.25)
Q3 = superstore.NumDealsPurchases.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
superstore = superstore[ (superstore.NumDealsPurchases >= lower_bound) & (superstore.NumDealsPurchases <= upper_bound) ]
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2148 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2148 non-null   int64
#  1   Year_Birth           2148 non-null   int64
#  2   Education            2148 non-null   object
#  3   Marital_Status       2148 non-null   object
#  4   Income               2148 non-null   float64
#  5   Kidhome              2148 non-null   int64
#  6   Teenhome             2148 non-null   int64
#  7   Dt_Customer          2148 non-null   object
#  8   Recency              2148 non-null   int64
#  9   MntWines             2148 non-null   int64
#  10  MntFruits            2148 non-null   int64
#  11  MntMeatProducts      2148 non-null   int64
#  12  MntFishProducts      2148 non-null   int64
#  13  MntSweetProducts     2148 non-null   int64
#  14  MntGoldProds         2148 non-null   int64
# ...

# %%
sns.boxplot(superstore.NumDealsPurchases)
# Out:
# <Axes: ylabel='NumDealsPurchases'>

# %% [markdown]
# # **NumStorePurchases**

# %%
sns.boxplot(superstore.NumStorePurchases)
# Out:
# <Axes: ylabel='NumStorePurchases'>

# %% [markdown]
# # **NumWebPurchases**

# %%
sns.boxplot(superstore.NumWebPurchases)
Q1 = superstore.NumWebPurchases.quantile(0.25)
Q3 = superstore.NumWebPurchases.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
superstore = superstore[ (superstore.NumWebPurchases >= lower_bound) & (superstore.NumWebPurchases <= upper_bound) ]
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2144 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2144 non-null   int64
#  1   Year_Birth           2144 non-null   int64
#  2   Education            2144 non-null   object
#  3   Marital_Status       2144 non-null   object
#  4   Income               2144 non-null   float64
#  5   Kidhome              2144 non-null   int64
#  6   Teenhome             2144 non-null   int64
#  7   Dt_Customer          2144 non-null   object
#  8   Recency              2144 non-null   int64
#  9   MntWines             2144 non-null   int64
#  10  MntFruits            2144 non-null   int64
#  11  MntMeatProducts      2144 non-null   int64
#  12  MntFishProducts      2144 non-null   int64
#  13  MntSweetProducts     2144 non-null   int64
#  14  MntGoldProds         2144 non-null   int64
# ...

# %%
sns.boxplot(superstore.NumWebPurchases)
# Out:
# <Axes: ylabel='NumWebPurchases'>

# %% [markdown]
# # **NumWebVisitsMonth**

# %%
sns.boxplot(superstore.NumWebVisitsMonth)
Q1 = superstore.NumWebVisitsMonth.quantile(0.25)
Q3 = superstore.NumWebVisitsMonth.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
superstore = superstore[ (superstore.NumWebVisitsMonth >= lower_bound) & (superstore.NumWebVisitsMonth <= upper_bound) ]
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2139 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2139 non-null   int64
#  1   Year_Birth           2139 non-null   int64
#  2   Education            2139 non-null   object
#  3   Marital_Status       2139 non-null   object
#  4   Income               2139 non-null   float64
#  5   Kidhome              2139 non-null   int64
#  6   Teenhome             2139 non-null   int64
#  7   Dt_Customer          2139 non-null   object
#  8   Recency              2139 non-null   int64
#  9   MntWines             2139 non-null   int64
#  10  MntFruits            2139 non-null   int64
#  11  MntMeatProducts      2139 non-null   int64
#  12  MntFishProducts      2139 non-null   int64
#  13  MntSweetProducts     2139 non-null   int64
#  14  MntGoldProds         2139 non-null   int64
# ...

# %%
sns.boxplot(superstore.NumWebVisitsMonth)
# Out:
# <Axes: ylabel='NumWebVisitsMonth'>

# %% [markdown]
# # **Recency**

# %%
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2139 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2139 non-null   int64
#  1   Year_Birth           2139 non-null   int64
#  2   Education            2139 non-null   object
#  3   Marital_Status       2139 non-null   object
#  4   Income               2139 non-null   float64
#  5   Kidhome              2139 non-null   int64
#  6   Teenhome             2139 non-null   int64
#  7   Dt_Customer          2139 non-null   object
#  8   Recency              2139 non-null   int64
#  9   MntWines             2139 non-null   int64
#  10  MntFruits            2139 non-null   int64
#  11  MntMeatProducts      2139 non-null   int64
#  12  MntFishProducts      2139 non-null   int64
#  13  MntSweetProducts     2139 non-null   int64
#  14  MntGoldProds         2139 non-null   int64
# ...

# %%
sns.boxplot(superstore.Recency)
# Out:
# <Axes: ylabel='Recency'>

# %% [markdown]
# # **Teenhome**

# %%
sns.boxplot(superstore.Teenhome)
# Out:
# <Axes: ylabel='Teenhome'>

# %% [markdown]
# # **Kidhome**

# %%
sns.boxplot(superstore.Kidhome)
# Out:
# <Axes: ylabel='Kidhome'>

# %% [markdown]
# # **Response**

# %%
sns.boxplot(superstore.Response)
# Out:
# <Axes: ylabel='Response'>

# %% [markdown]
# # **Complain**

# %%
sns.boxplot(superstore.Complain)
# Out:
# <Axes: ylabel='Complain'>

# %% [markdown]
# ## **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:
#
# ## **Conclusion of Task 2**
#
# It can be observed from the above codes, that the desciptive statistics of the data has been deveeloped. It also shows the different relevant box plots. The boxplot shows different outlier values but it can be considered as Anomaly as the values for the columns are not invalid although it does not occur occatinally in the data.

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %%
import scipy.stats
from scipy.stats import norm

# %% [markdown]
# # **Income**

# %%
plt.hist(superstore.Income, bins=30, density=True, alpha=0.6, color='g')
plt.title('Probability Distribution Function of Income')
plt.xlabel('RMV Value')
plt.ylabel('Probability Density')

x = np.linspace(superstore['Income'].min(), superstore['Income'].max(), 100)
p = norm.pdf(x, np.mean(superstore.Income), np.std(superstore.Income))
plt.plot(x, p, 'k', linewidth=2)
expected_value = np.sum(x*p)
plt.legend(title = f'Expected Value {round(expected_value)}', loc=1)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # **NumDealsPurchases**

# %%
plt.hist(superstore.NumDealsPurchases, bins=50, density=True, alpha=0.6, color='g')
plt.title('Probability Distribution Function of NumDealsPurchases')
plt.xlabel('RMV Value')
plt.ylabel('Probability Density')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, np.mean(superstore.NumDealsPurchases), np.std(superstore.NumDealsPurchases))
plt.plot(x, p, 'k', linewidth=2)
expected_value = np.sum(x*p)
plt.legend(title = f'Expected Value {round(expected_value,2)}', loc=1)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # **NumStorePurchases**

# %%
plt.hist(superstore.NumStorePurchases, bins=50, density=True, alpha=0.6, color='g')
plt.title('Probability Distribution Function of NumStorePurchases')
plt.xlabel('RMV Value')
plt.ylabel('Probability Density')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, np.mean(superstore.NumStorePurchases), np.std(superstore.NumStorePurchases))
plt.plot(x, p, 'k', linewidth=2)
expected_value = np.sum(x*p)
plt.legend(title = f'Expected Value {round(expected_value,2)}', loc=1)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # **NumWebPurchases**

# %%
plt.hist(superstore.NumWebPurchases, bins=50, density=True, alpha=0.6, color='g')
plt.title('Probability Distribution Function of NumWebPurchases')
plt.xlabel('RMV Value')
plt.ylabel('Probability Density')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, np.mean(superstore.NumWebPurchases), np.std(superstore.NumWebPurchases))
plt.plot(x, p, 'k', linewidth=2)
expected_value = np.sum(x*p)
plt.legend(title = f'Expected Value {round(expected_value,2)}', loc=1)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # **NumWebVisitsMonth**

# %%
plt.hist(superstore.NumWebVisitsMonth, bins=50, density=True, alpha=0.6, color='g')
plt.title('Probability Distribution Function of NumWebVisitsMonth')
plt.xlabel('RMV Value')
plt.ylabel('Probability Density')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, np.mean(superstore.NumWebVisitsMonth), np.std(superstore.NumWebVisitsMonth))
plt.plot(x, p, 'k', linewidth=2)
expected_value = np.sum(x*p)
plt.legend(title = f'Expected Value {round(expected_value,2)}', loc=1)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # **Recency**

# %%
plt.hist(superstore.Recency, bins=50, density=True, alpha=0.6, color='g')
plt.title('Probability Distribution Function of Recency')
plt.xlabel('RMV Value')
plt.ylabel('Probability Density')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, np.mean(superstore.Recency), np.std(superstore.Recency))
plt.plot(x, p, 'k', linewidth=2)
expected_value = np.sum(x*p)
plt.legend(title = f'Expected Value {round(expected_value,2)}', loc=1)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %% [markdown]
# ## **Conclusion of Task 3**
#
# This task shows different probability distribution and only Income and Recency have proper normal distribution after the IQR adjustements with the data. This shows that the probability distributions are properly aggregated and it provides support to the following segementation of the data.

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# # **Age Column Creation**

# %%
import datetime

today = datetime.date.today()
today.year
# Out:
# 2024

# %%
superstore['Age'] = (today.year - superstore['Year_Birth'])

# %%
superstore.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntSweetProducts  MntGoldProds  \
# 0   6/16/2014        0       189  ...               189           218
# 1   6/15/2014        0       464  ...                 0            37
# 2   5/13/2014        0       134  ...                 2            30
# 3    ########        0        10  ...                 0             0
# 4    ########        0         6  ...                 0            34
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# ...

# %%
sns.boxplot(superstore.Age)
Q1 = superstore.Age.quantile(0.25)
Q3 = superstore.Age.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
superstore = superstore[ (superstore.Age >= lower_bound) & (superstore.Age <= upper_bound) ]
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2136 entries, 0 to 2239
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2136 non-null   int64
#  1   Year_Birth           2136 non-null   int64
#  2   Education            2136 non-null   object
#  3   Marital_Status       2136 non-null   object
#  4   Income               2136 non-null   float64
#  5   Kidhome              2136 non-null   int64
#  6   Teenhome             2136 non-null   int64
#  7   Dt_Customer          2136 non-null   object
#  8   Recency              2136 non-null   int64
#  9   MntWines             2136 non-null   int64
#  10  MntFruits            2136 non-null   int64
#  11  MntMeatProducts      2136 non-null   int64
#  12  MntFishProducts      2136 non-null   int64
#  13  MntSweetProducts     2136 non-null   int64
#  14  MntGoldProds         2136 non-null   int64
# ...

# %%
sns.boxplot(superstore.Age)
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# # **Wine Buying for different segments of customers**

# %%
eduction_wine = superstore.groupby('Education').agg(wine_con = ('MntWines','mean'))
marriage_wine = superstore.groupby('Marital_Status').agg(wine_con = ('MntWines','mean'))
print(marriage_wine)
print(eduction_wine)
# Out:
#                   wine_con
# Marital_Status
# Absurd          355.500000
# Alone           184.666667
# Divorced        324.049774
# Married         296.565534
# Single          291.165577
# Together        302.091075
# Widow           367.710526
# YOLO            322.000000
#               wine_con
# Education
# 2n Cycle    191.035897
# Basic         7.240741
# Graduation  283.728625
# Master      327.817664
# PhD         407.247826

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
sns.barplot(ax = axes[0,0], data = eduction_wine, x = eduction_wine.index,y = 'wine_con')
axes[0,0].bar_label(axes[0,0].containers[0])
axes[0,0].set_title('Wine Consumption of different education background')

sns.barplot(ax = axes[0,1], data = marriage_wine, x = marriage_wine.index,y = 'wine_con')
axes[0,1].bar_label(axes[0,1].containers[0])
axes[0,1].set_title('Wine Consumption of different mareital status')

sns.regplot(ax = axes[1,0], x='Age',y='MntWines',data=superstore)
axes[1,0].set_title('Wine Consumption of different Ages')

sns.regplot(ax = axes[1,1],x='Income',y='MntWines',data=superstore)
axes[1,1].set_title('Wine Consumption of different Income')

plt.tight_layout()

# %% [markdown]
# # **Fruit Buying for different segments of customers**

# %%
eduction_fruit = superstore.groupby('Education').agg(fruit_con = ('MntFruits','mean'))
marriage_fruit = superstore.groupby('Marital_Status').agg(fruit_con = ('MntFruits','mean'))
print(marriage_fruit)
print(eduction_fruit)
# Out:
#                 fruit_con
# Marital_Status
# Absurd          84.500000
# Alone            4.000000
# Divorced        28.375566
# Married         26.489078
# Single          26.572985
# Together        25.593807
# Widow           33.223684
# YOLO             3.000000
#             fruit_con
# Education
# 2n Cycle    29.123077
# Basic       11.111111
# Graduation  31.197026
# Master      22.455840
# PhD         20.280435

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
sns.barplot(ax = axes[0,0], data = eduction_fruit, x = eduction_fruit.index,y = 'fruit_con')
axes[0,0].bar_label(axes[0,0].containers[0])
axes[0,0].set_title('Fruit Consumption of different education background')

sns.barplot(ax = axes[0,1], data = marriage_fruit, x = marriage_fruit.index,y = 'fruit_con')
axes[0,1].bar_label(axes[0,1].containers[0])
axes[0,1].set_title('Fruit Consumption of different mareital status')

sns.regplot(ax = axes[1,0], x='Age',y='MntFruits',data=superstore)
axes[1,0].set_title('Fruit Consumption of different Ages')

sns.regplot(ax = axes[1,1],x='Income',y='MntFruits',data=superstore)
axes[1,1].set_title('Fruit Consumption of different Income')

plt.tight_layout()

# %% [markdown]
# # **Meat Buying for different segments of customers**

# %%
eduction_meat = superstore.groupby('Education').agg(meat_con = ('MntMeatProducts','mean'))
marriage_meat = superstore.groupby('Marital_Status').agg(meat_con = ('MntMeatProducts','mean'))
print(marriage_meat)
print(eduction_meat)
# Out:
#                   meat_con
# Marital_Status
# Absurd          312.500000
# Alone            26.333333
# Divorced        151.841629
# Married         157.843447
# Single          184.690632
# Together        166.856102
# Widow           190.842105
# YOLO             50.000000
#               meat_con
# Education
# 2n Cycle    141.923077
# Basic        11.444444
# Graduation  178.666357
# Master      168.159544
# PhD         164.658696

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
sns.barplot(ax = axes[0,0], data = eduction_meat, x = eduction_meat.index,y = 'meat_con')
axes[0,0].bar_label(axes[0,0].containers[0])
axes[0,0].set_title('Meat Consumption of different education background')

sns.barplot(ax = axes[0,1], data = marriage_meat, x = marriage_meat.index,y = 'meat_con')
axes[0,1].bar_label(axes[0,1].containers[0])
axes[0,1].set_title('Meat Consumption of different mareital status')

sns.regplot(ax = axes[1,0], x='Age',y='MntMeatProducts',data=superstore)
axes[1,0].set_title('Meat Consumption of different Ages')

sns.regplot(ax = axes[1,1],x='Income',y='MntMeatProducts',data=superstore)
axes[1,1].set_title('Meat Consumption of different Income')

plt.tight_layout()

# %% [markdown]
# # **Fish Buying for different segments of customers**

# %%
eduction_fish = superstore.groupby('Education').agg(fish_con = ('MntFishProducts','mean'))
marriage_fish = superstore.groupby('Marital_Status').agg(fish_con = ('MntFishProducts','mean'))
print(marriage_fish)
print(eduction_fish)
# Out:
#                   fish_con
# Marital_Status
# Absurd          205.500000
# Alone             7.666667
# Divorced         35.923077
# Married          36.411408
# Single           38.455338
# Together         38.996357
# Widow            51.868421
# YOLO              4.000000
#              fish_con
# Education
# 2n Cycle    46.615385
# Basic       17.055556
# Graduation  43.969331
# Master      32.957265
# PhD         27.165217

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
sns.barplot(ax = axes[0,0], data = eduction_fish, x = eduction_fish.index,y = 'fish_con')
axes[0,0].bar_label(axes[0,0].containers[0])
axes[0,0].set_title('Fish Consumption of different education background')

sns.barplot(ax = axes[0,1], data = marriage_fish, x = marriage_fish.index,y = 'fish_con')
axes[0,1].bar_label(axes[0,1].containers[0])
axes[0,1].set_title('Fish Consumption of different mareital status')

sns.regplot(ax = axes[1,0], x='Age',y='MntFishProducts',data=superstore)
axes[1,0].set_title('Fish Consumption of different Ages')

sns.regplot(ax = axes[1,1],x='Income',y='MntFishProducts',data=superstore)
axes[1,1].set_title('Fish Consumption of different Income')

plt.tight_layout()

# %% [markdown]
# # **Sweet Buying for different segments of customers**

# %%
eduction_sweet = superstore.groupby('Education').agg(sweet_con = ('MntSweetProducts','mean'))
marriage_sweet = superstore.groupby('Marital_Status').agg(sweet_con = ('MntSweetProducts','mean'))
print(marriage_sweet)
print(eduction_sweet)
# Out:
#                 sweet_con
# Marital_Status
# Absurd          30.500000
# Alone            7.000000
# Divorced        27.126697
# Married         27.326456
# Single          26.681917
# Together        26.102004
# Widow           39.526316
# YOLO             3.000000
#             sweet_con
# Education
# 2n Cycle    33.333333
# Basic       12.111111
# Graduation  31.874535
# Master      21.339031
# PhD         20.086957

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
sns.barplot(ax = axes[0,0], data = eduction_sweet, x = eduction_sweet.index,y = 'sweet_con')
axes[0,0].bar_label(axes[0,0].containers[0])
axes[0,0].set_title('Sweet Consumption of different education background')

sns.barplot(ax = axes[0,1], data = marriage_sweet, x = marriage_sweet.index,y = 'sweet_con')
axes[0,1].bar_label(axes[0,1].containers[0])
axes[0,1].set_title('Sweet Consumption of different mareital status')

sns.regplot(ax = axes[1,0], x='Age',y='MntSweetProducts',data=superstore)
axes[1,0].set_title('Sweet Consumption of different Ages')

sns.regplot(ax = axes[1,1],x='Income',y='MntSweetProducts',data=superstore)
axes[1,1].set_title('Sweet Consumption of different Income')

plt.tight_layout()

# %% [markdown]
# # **Gold Buying for different segments of customers**

# %%
eduction_gold = superstore.groupby('Education').agg(gold_con = ('MntGoldProds','mean'))
marriage_gold = superstore.groupby('Marital_Status').agg(gold_con = ('MntGoldProds','mean'))
print(marriage_gold)
print(eduction_gold)
# Out:
#                   gold_con
# Marital_Status
# Absurd          204.000000
# Alone            27.000000
# Divorced         45.963801
# Married          41.894417
# Single           41.150327
# Together         42.174863
# Widow            56.736842
# YOLO             42.000000
#              gold_con
# Education
# 2n Cycle    45.189744
# Basic       22.833333
# Graduation  49.859665
# Master      38.558405
# PhD         31.256522

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
sns.barplot(ax = axes[0,0], data = eduction_gold, x = eduction_gold.index,y = 'gold_con')
axes[0,0].bar_label(axes[0,0].containers[0])
axes[0,0].set_title('Gold Consumption of different education background')

sns.barplot(ax = axes[0,1], data = marriage_gold, x = marriage_gold.index,y = 'gold_con')
axes[0,1].bar_label(axes[0,1].containers[0])
axes[0,1].set_title('Gold Consumption of different mareital status')

sns.regplot(ax = axes[1,0], x='Age',y='MntGoldProds',data=superstore)
axes[1,0].set_title('Gold Consumption of different Ages')

sns.regplot(ax = axes[1,1],x='Income',y='MntGoldProds',data=superstore)
axes[1,1].set_title('Gold Consumption of different Income')

plt.tight_layout()

# %% [markdown]
# # **NumDealPurchases for different segments of customers**

# %%
eduction_deal_purchase = superstore.groupby('Education').agg(deal_purchase = ('NumDealsPurchases','mean'))
marriage_deal_purchase = superstore.groupby('Marital_Status').agg(deal_purchase = ('NumDealsPurchases','mean'))
print(marriage_deal_purchase)
print(eduction_deal_purchase)
# Out:
#                 deal_purchase
# Marital_Status
# Absurd               2.000000
# Alone                3.666667
# Divorced             2.230769
# Married              2.088592
# Single               1.945534
# Together             2.072860
# Widow                2.223684
# YOLO                 5.000000
#             deal_purchase
# Education
# 2n Cycle         2.030769
# Basic            1.796296
# Graduation       2.070632
# Master           2.139601
# PhD              2.102174

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
sns.barplot(ax = axes[0,0], data = eduction_deal_purchase, x = eduction_deal_purchase.index,y = 'deal_purchase')
axes[0,0].bar_label(axes[0,0].containers[0])
axes[0,0].set_title('Deal Purchases of different education background')

sns.barplot(ax = axes[0,1], data = marriage_deal_purchase, x = marriage_deal_purchase.index,y = 'deal_purchase')
axes[0,1].bar_label(axes[0,1].containers[0])
axes[0,1].set_title('Deal Purchases of different mareital status')

sns.regplot(ax = axes[1,0], x='Age',y='NumDealsPurchases',data=superstore)
axes[1,0].set_title('Deal Purchases of different Ages')

sns.regplot(ax = axes[1,1],x='Income',y='NumDealsPurchases',data=superstore)
axes[1,1].set_title('Deal Purchases of different Income')

plt.tight_layout()

# %% [markdown]
# # **NumWebPurchases for different segments of customers**

# %%
eduction_web_purchase = superstore.groupby('Education').agg(web_purchase = ('NumWebPurchases','mean'))
marriage_web_purchase = superstore.groupby('Marital_Status').agg(web_purchase = ('NumWebPurchases','mean'))
print(marriage_web_purchase)
print(eduction_web_purchase)
# Out:
#                 web_purchase
# Marital_Status
# Absurd              3.500000
# Alone               5.000000
# Divorced            4.294118
# Married             4.016990
# Single              3.677560
# Together            3.983607
# Widow               4.578947
# YOLO                7.000000
#             web_purchase
# Education
# 2n Cycle        3.697436
# Basic           1.888889
# Graduation      4.017658
# Master          3.951567
# PhD             4.315217

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
sns.barplot(ax = axes[0,0], data = eduction_web_purchase, x = eduction_web_purchase.index,y = 'web_purchase')
axes[0,0].bar_label(axes[0,0].containers[0])
axes[0,0].set_title('Web Purchases of different education background')

sns.barplot(ax = axes[0,1], data = marriage_web_purchase, x = marriage_web_purchase.index,y = 'web_purchase')
axes[0,1].bar_label(axes[0,1].containers[0])
axes[0,1].set_title('Web Purchases of different mareital status')

sns.regplot(ax = axes[1,0], x='Age',y='NumWebPurchases',data=superstore)
axes[1,0].set_title('Web Purchases of different Ages')

sns.regplot(ax = axes[1,1],x='Income',y='NumWebPurchases',data=superstore)
axes[1,1].set_title('Web Purchases of different Income')

plt.tight_layout()

# %% [markdown]
# # **NumCatalogPurchases for different segments of customers**

# %%
eduction_catalogue_purchase = superstore.groupby('Education').agg(catalogue_purchase = ('NumCatalogPurchases','mean'))
marriage_catalogue_purchase = superstore.groupby('Marital_Status').agg(catalogue_purchase = ('NumCatalogPurchases','mean'))
print(marriage_catalogue_purchase)
print(eduction_catalogue_purchase)
# Out:
#                 catalogue_purchase
# Marital_Status
# Absurd                    7.500000
# Alone                     0.666667
# Divorced                  2.674208
# Married                   2.553398
# Single                    2.636166
# Together                  2.621129
# Widow                     3.328947
# YOLO                      1.000000
#             catalogue_purchase
# Education
# 2n Cycle              2.297436
# Basic                 0.481481
# Graduation            2.699814
# Master                2.555556
# PhD                   2.913043

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
sns.barplot(ax = axes[0,0], data = eduction_catalogue_purchase, x = eduction_catalogue_purchase.index,y = 'catalogue_purchase')
axes[0,0].bar_label(axes[0,0].containers[0])
axes[0,0].set_title('Catalogue Purchases of different education background')

sns.barplot(ax = axes[0,1], data = marriage_catalogue_purchase, x = marriage_catalogue_purchase.index,y = 'catalogue_purchase')
axes[0,1].bar_label(axes[0,1].containers[0])
axes[0,1].set_title('Catalogue Purchases of different mareital status')

sns.regplot(ax = axes[1,0], x='Age',y='NumCatalogPurchases',data=superstore)
axes[1,0].set_title('Catalogue Purchases of different Ages')

sns.regplot(ax = axes[1,1],x='Income',y='NumCatalogPurchases',data=superstore)
axes[1,1].set_title('Catalogue Purchases of different Income')

plt.tight_layout()

# %% [markdown]
# # **NumStorePurchases for different segments of customers**

# %%
eduction_store_purchase = superstore.groupby('Education').agg(store_purchase = ('NumStorePurchases','mean'))
marriage_store_purchase = superstore.groupby('Marital_Status').agg(store_purchase = ('NumStorePurchases','mean'))
print(marriage_store_purchase)
print(eduction_store_purchase)
# Out:
#                 store_purchase
# Marital_Status
# Absurd                6.500000
# Alone                 4.000000
# Divorced              5.886878
# Married               5.831311
# Single                5.660131
# Together              5.739526
# Widow                 6.407895
# YOLO                  6.000000
#             store_purchase
# Education
# 2n Cycle          5.497436
# Basic             2.851852
# Graduation        5.830855
# Master            5.857550
# PhD               6.136957

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
sns.barplot(ax = axes[0,0], data = eduction_store_purchase, x = eduction_store_purchase.index,y = 'store_purchase')
axes[0,0].bar_label(axes[0,0].containers[0])
axes[0,0].set_title('Store Purchases of different education background')

sns.barplot(ax = axes[0,1], data = marriage_store_purchase, x = marriage_store_purchase.index,y = 'store_purchase')
axes[0,1].bar_label(axes[0,1].containers[0])
axes[0,1].set_title('Store Purchases of different mareital status')

sns.regplot(ax = axes[1,0], x='Age',y='NumStorePurchases',data=superstore)
axes[1,0].set_title('Store Purchases of different Ages')

sns.regplot(ax = axes[1,1],x='Income',y='NumStorePurchases',data=superstore)
axes[1,1].set_title('Store Purchases of different Income')

plt.tight_layout()

# %% [markdown]
# # **NumWebVisitsMonth for different segments of customers**

# %%
eduction_visits_month = superstore.groupby('Education').agg(visits_month = ('NumWebVisitsMonth','mean'))
marriage_visits_month = superstore.groupby('Marital_Status').agg(visits_month = ('NumWebVisitsMonth','mean'))
print(marriage_visits_month)
print(eduction_visits_month)
# Out:
#                 visits_month
# Marital_Status
# Absurd              1.500000
# Alone               6.333333
# Divorced            5.361991
# Married             5.316748
# Single              5.183007
# Together            5.173042
# Widow               4.855263
# YOLO                8.000000
#             visits_month
# Education
# 2n Cycle        5.410256
# Basic           6.870370
# Graduation      5.202602
# Master          5.076923
# PhD             5.186957

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
sns.barplot(ax = axes[0,0], data = eduction_visits_month, x = eduction_visits_month.index,y = 'visits_month')
axes[0,0].bar_label(axes[0,0].containers[0])
axes[0,0].set_title('Number of Visits of different education background')

sns.barplot(ax = axes[0,1], data = marriage_visits_month, x = marriage_visits_month.index,y = 'visits_month')
axes[0,1].bar_label(axes[0,1].containers[0])
axes[0,1].set_title('Number of Visits of different mareital status')

sns.regplot(ax = axes[1,0], x='Age',y='NumWebVisitsMonth',data=superstore)
axes[1,0].set_title('Number of Visits of different Ages')

sns.regplot(ax = axes[1,1],x='Income',y='NumWebVisitsMonth',data=superstore)
axes[1,1].set_title('Number of Visits of different Income')

plt.tight_layout()

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# The Graphical Representations in Task 4 shows different segments of the customer and also the relation of different purchases based on Income and Age.
# This enlightens on the insights of the customrs and it reveals buyer and consumer behaviour based on the measurand factors. This relationship helps develop marketing strategy which helps determine how to project their products in different segments.

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
